# %% [markdown]
# <a href="https://colab.research.google.com/github/ilginkarakas/GlobalAIHubPythonCourse/blob/master/HomeworkDay5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HomeworkDay5

#for Animals
class Animals:
  #FEATURES
  def __init__ (self, n=' ',f=' ',e=' ',t=' ',g= ' '):
    self.name =n
    self.furcolour=f
    self.extant=e
    self.animaltype=t
    self.group=g
  def setName(self,n) :
      self.name=n
  def getName(self) :
      return self.name
  def setFurcolour(self,f) :
      self.furcolour=f
  def getFurcolour(self) :
      return self.furcolour
  def setExtant(self,e) :
      self.extant=e
  def getExtant(self) :
      return self.extant
  def setAnimalType(self,t) :
      self.animaltype=t
  def getAnimalType(self) :
      return self.animaltype
  def setGroup(self,g) :
      self.group=g
  def getgroup(self) :
      return self.group

  def message (self) :            
      print(" The {0} has {1}. The {0} is {2}. The {0} is in the group of {3} and {4}  ".format (self.name,self.furcolour,self.extant,self.animaltype, self.group))      
  
#For Dogs
class Dogs(Animals):
  #FEATURES
  def __init__ (self, n=' ',f=' ',e=' ',t=' ',g= ' '):
    self.name =n
    self.furcolour=f
    self.extant=e
    self.animaltype=t
    self.group=g
  def setName (self, n) :
      self.name=n
  def getName (self) :
      return self.name
  def setFurcolour (self,f) :
      self.furcolour=f
  def getFurcolour (self) :
      return self.furcolour
  def setExtant (self,e) :
      self.extant=e
  def getExtant (self) :
      return self.extant
  def setAnimalType (self,t) :
      self.animaltype=t
  def getAnimalType (self) :
      return self.animaltype
  def setGroup (self,g) :
      self.group=g
  def getgroup (self) :
      return self.group

  def setType (self) :            
      print(" The {0} has {1 }. The { 0} is { 2}. The {0 } is in the group of { 3} and { 4}  ".format (self.name,self.furcolour,self.extant,self.animaltype, self.group))

 #For Cats
class Cats(Animals):
  #FEATURES
  def __init__ (self, n=' ',f=' ',e=' ',t=' ',g= ' '):
    self.name =n
    self.furcolour=f
    self.extant=e
    self.animaltype=t
    self.group=g
  def setName (self,n) :
      self.name=n
  def getName(self) :
      return self.name
  def setFurcolour(self,f) :
      self.furcolour=f
  def getFurcolour(self) :
      return self.furcolour
  def setExtant(self,e) :
      self.extant=e
  def getExtant(self) :
      return self.extant
  def setAnimalType(self,t) :
      self.animaltype=t
  def getAnimalType(self) :
      return self.animaltype
  def setGroup(self,g) :
      self.group=g
  def getgroup(self) :
      return self.group

  def setType (self) :            
      print(" The {0} has {1 }. The { 0} is { 2}. The {0 } is in the group of { 3} and { 4}  ".format (self.name,self.furcolour,self.extant,self.animaltype, self.group))
  
  
  doggo=Dogs('Kekik','Blonde','unextinct','mammals','vertebrata' )
  doggo.message()   

  katze=Cats('Minnoş','spotted/black and white','unextinct','mammals','vertebrata') 
  katze.message()

  reptile=Animals('Luna','striped/green','extinct','reptile','invertebrates')
  reptile.message()
# Out:
#  The Kekik has Blonde. The Kekik is unextinct. The Kekik is in the group of mammals and vertebrata
#  The Minnoş has spotted. The Minnoş is unextinct. The Minnoş is in mammals and vertebrata
#  The Luna has striped. The Luna is extinct. The Luna is in the group of reptile and invertebrates
